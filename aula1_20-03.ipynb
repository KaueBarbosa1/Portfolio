# %%
altura = 1.79
peso = 68.7

# %%
altura
# Out:
# 1.79

# %%
68.7 / 1.79 ** 2
# Out:
# 21.44127836209856

# %%
peso / altura ** 2
# Out:
# 21.44127836209856

# %%
bmi = peso / altura ** 2
bmi
print(bmi)
# Out:
# 21.44127836209856

# %%
type(bmi)
# Out:
# float

# %%
day_of_week = 5
type(day_of_week)
# Out:
# int

# %%
x = "body mass index"
y = "this works too"
type(y)
# Out:
# str

# %%
z = True
type(z)
# Out:
# bool

# %%
k = "kaue"
m = "fofo"
print(k+m)
# Out:
# kauefofo

# %%
# Example
print(5 / 8)
# Out:
# 0.625

# %%
7 + 8
print(7 + 8)
# Example
# Out:
# 15

# %%
5 + 3
print(5 + 3)
5 - 3
# Out:
# 8
# 2

# %%
5 ** 3
print(5 ** 3)
5 / 3
print(5 / 3)
# Out:
# 125
# 1.6666666666666667

# %%
100 / 1.1
day_of_year = 7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c0364c75f8ea> in <module>
#       1 100 / 1.1
#       2 day_of_year = 7
# ----> 3 print(bmi)
#
# NameError: name 'bmi' is not defined
