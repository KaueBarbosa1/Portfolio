# %%
((100 * 11/100) * 11/100)
# Out:
# 1.21

# %%
ganho = (100 * (11/100))**7
ganho
# Out:
# 19487171.0

# %%
saving = 100
growth_multiplier = 1.1
desc = "compound interest "
year1 = (saving + growth_multiplier)
print(type (year1))
double_desc = desc + desc
print(double_desc)
# Out:
# <class 'float'>
# compound interest compound interest

# %%
pi_string = "3.14"
pi_float = float(pi_string)
print(type(pi_float))
print(type(pi_string))
# Out:
# <class 'float'>
# <class 'str'>

# %%
saving = 100
result = 100 * 1.10 ** 7
print("I started with $" + str(saving) + " and now have $" + str(result) + ". Awesome!")
# O erro acontece pelo fato de ter numeros e letras juntas.
# Out:
# I started with $100 and now have $194.87171000000012. Awesome!

# %%
true + false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-0478bc12a5ac> in <module>
# ----> 1 true + false
#
# NameError: name 'true' is not defined
